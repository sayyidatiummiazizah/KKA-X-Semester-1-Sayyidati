# %% [markdown]
# <a href="https://colab.research.google.com/github/sayyidatiummiazizah/KKA-X-Semester-1-Sayyidati/blob/main/Tipe_variabel_sayyidati_u_a_x_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Sayyidati Ummi A
#
# Kelas:X.2
#
# No.absen:29

# %% [markdown]
# Konsep Dasar Variabel

# %%
print("sayyidatiummiazizah.2025@gmail.com ")
print("sayyidatiummiazizah.2025@gmail.com ")
print ("sayyidatiummiazizah.2025@gmail.com ")
# Out:
# sayyidatiummiazizah.2025@gmail.com
# sayyidatiummiazizah.2025@gmail.com
# sayyidatiummiazizah.2025@gmail.com

# %%
email_user = "sayyidatiummiazizah.2025@gmail.com "
print(email_user)
print(email_user)
print(email_user)
# Out:
# sayyidatiummiazizah.2025@gmail.com
# sayyidatiummiazizah.2025@gmail.com
# sayyidatiummiazizah.2025@gmail.com

# %%
hargatelur = 15000
print (hargatelur)
# Out:
# 15000

# %%
nama_siswa = "AhmAhmad Dhani"
print (nama_siswa)
# Out:
# AhmAhmad Dhani

# %%
IF = "Handayani"
print (IF)
# Out:
# Handayani

# %%
print = "Noor"
prin("print")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-497764750.py in <cell line: 0>()
#       1 print = "Noor"
# ----> 2 prin("print")
#
# NameError: name 'prin' is not defined

# %%
Print = "Noor"
print(Print)
# Out:
# Noor

# %%
USIA = 17

print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3366841127.py in <cell line: 0>()
#       1 USIA = 17
#       2
# ----> 3 print(Usia)
#
# NameError: name 'Usia' is not defined

# %%
Print = "USIA"
print(Print)
# Out:
# USIA

# %%
  _ = "Fazel Wardana"

# %%
  _ = "LiaLia Wati"

# %%
   print (_)
# Out:
# LiaLia Wati

# %% [markdown]
# Assignment

# %%
#single assignment
bb_fazel =55
bb_dani =60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#multiple assignment
bb_fazel, bb_dani = 55, 60
print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel, bb_dani = 55, 60, 70
print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-512873506.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani = 55, 60, 70
#       2 print(bb_dani)
#       3 print(bb_fazel)
#
# ValueError: too many values to unpack (expected 2)

# %%
nama_siswa_1, nama_siswa_2 = "deni", "doni

Print(nama_siswa_1)
Print(nama_siswa_2)
# Out:
#   File "/tmp/ipython-input-24779750.py", line 1
#     nama_siswa_1, nama_siswa_2 = "deni", "doni
#                                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
bb_fazel, bb_dani, bb_adli, = 55, 60

print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4189733851.py in <cell line: 0>()
# ----> 1 bb_fazel, bb_dani, bb_adli, = 55, 60
#       2
#       3 print(bb_dani)
#       4 print(bb_fazel)
#       5
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#chain assighment
bb_hasbi = bb_dani = 60

print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %% [markdown]
# soal coding assignment

# %%
nama = "Andi"
print(nama)
# Out:
# Andi

# %%
nama,  umur, kelas = "Budi", 15, "9A"
print(nama, umur, kelas)
# Out:
# Budi 15 9A

# %%
berat_andi = berat_siti = berat_eko = 45.5
print(berat_andi, berat_siti, berat_eko)
# Out:
# 45.5 45.5 45.5

# %%
#jumlah botol per kardus 24, jumlah kardus 3
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print(banyak_botol_per_kardus * jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus * jumlah_kardus
print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# jenis jenis tipe variabel

# %%
a = 0
print(a)
type(a)
# Out:
# 0
# int

# %%
b = 0.0
print(b)
type(b)
# Out:
# 0.0
# float

# %%
c = "yanto"
print(c)
type(c)
# Out:
# yanto
# str

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3721722550.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
e = False
print(e)
type(e)
# Out:
# False
# bool

# %%
f = 9,9
print(f)
type(f)
# Out:
# (9, 9)
# tuple

# %%
type(8.1)
# Out:
# float

# %% [markdown]
# mengubah tipe variabel

# %%
x = 8
print(x)
type(x)
# Out:
# 8
# int

# %%
x = float(x)
print(x)
type(x)
# Out:
# 8.0
# float

# %%
z = 10
print(z)
type(z)
# Out:
# 10
# int

# %%
z = float(z)
print(z)
type(z)
# Out:
# 10.0
# float

# %%
k = True
print(k)
type(k)
# Out:
# True
# bool

# %%
k = int(k)
print(k)
type(k)
# Out:
# 1
# int

# %%
m = 2
print(m)
type(m)
# Out:
# 2
# int

# %%
m = bool(m)
print(m)
type(m)
# Out:
# True
# bool

# %%
n = 0.0
print(n)
type(n)
# Out:
# 0.0
# float

# %%
n = bool(n)
print(n)
type(n)
# Out:
# False
# bool

# %%
h = float(5)
print(h)
type(h)
# Out:
# 5.0
# float

# %%
#tanpa variabel
print(9+6)
# Out:
# 15

# %%
print("yiran")
# Out:
# yiran

# %%
print("9+6")
# Out:
# 9+6

# %%
#operand disimpan ke variabel
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

print( jumlah_hp_habibi + jumlah_hp_syauqi )
# Out:
# 16

# %%
#Hasil operasi disimpan ke variabel
total_hp = 10 + 6

print (total_hp)
# Out:
# 16

# %%
#operand dan hasil operasi disimpan ke variabel
jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

total_hp = jumlah_hp_habibi + jumlah_hp_syauqi

print(total_hp)
# Out:
# 16

# %% [markdown]
# operator perbandingan

# %%
print( 5 >3 )
# Out:
# True

# %%
print(5 < 3 )
# Out:
# False

# %%
print( 5 >= 5 )
# Out:
# True

# %%
print( 6 >= 5 )
# Out:
# True

# %%
print( 6 <= 5 )
# Out:
# False

# %%
print( 6 != 6 )
# Out:
# False

# %%
print( 7 == 8 )
# Out:
# False

# %% [markdown]
# operator logika

# %%
print(6>=6)
print(8==9)
print(8!=9)
print(8<10)
print(8>10)
# Out:
# True
# False
# True
# True
# False

# %%
print(not(5<=5))
print(8>7 and 6<5)
print(7<=1 or 2!=2)
print(not(0==1 and 1!=1))
print(not(5<10 or 5<=10))
# Out:
# False
# False
# False
# True
# False
