# %% [markdown]
# <a href="https://colab.research.google.com/github/sayyidatiummiazizah/KKA-X-Semester-1-Sayyidati/blob/main/4_Aplikasi_kalkulator_sederhana_sayyidati_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cuypanjang = int(input("masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("mmasukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")
# Out:
# masukkan panjang dari persegi panjang (cm): 5
# mmasukkan lebar dari persegi panjang (cm): 4
#
# Luas dari persegi panjang yaitu 20 cm^2

# %%
r = int(input("Masukkan jari jari dari bangun kerucut (cm) : "))
t = int(input("Masukkan tinggi bangun kerucut (cm) : "))

volume = 1/3 * r**22 * t

print(f"\nVolume dari bangun kerucut yaitu {volume} cm^3")
# Out:
# Masukkan jari jari dari bangun kerucut (cm) : 7
# Masukkan tinggi bangun kerucut (cm) : 9
#
# Volume dari bangun kerucut yaitu 1.1729463145748965e+19 cm^3
